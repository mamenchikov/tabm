# %%
import h5py
import torch
import numpy as np
import matplotlib.pyplot as plt

DTYPE = torch.float32
DEVICE = 'cuda:0'

# %%
with h5py.File('exp/reproduce/mlp_periodic_adult_frozen/0/exp_data.h5', 'r') as f:
    try:
        w = f['weights'][()]
    except:
        pass
    l = f['losses'][()]

# %%
plt.plot(l[0,1:])

# %%
plt.plot(w[:,2,45])
